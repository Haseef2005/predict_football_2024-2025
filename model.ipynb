# %%
import pandas as pd

# %%
# index_col = 0 mean i will not get index as a column name 
df = pd.read_csv('matches.csv', index_col=0)

# %%
df.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 0  2024-08-17  12:30  Premier League  Matchweek 1  Sat  Away      W  2.0  0.0
# 1  2024-08-25  16:30  Premier League  Matchweek 2  Sun  Home      W  2.0  0.0
# 2  2024-09-01  16:00  Premier League  Matchweek 3  Sun  Away      W  3.0  0.0
# 3  2024-09-14  15:00  Premier League  Matchweek 4  Sat  Home      L  0.0  1.0
# 5  2024-09-21  15:00  Premier League  Matchweek 5  Sat  Home      W  3.0  0.0
#
#           opponent  ...  match report  notes    sh   sot  dist   fk pk pkatt  \
# 0     Ipswich Town  ...  Match Report    NaN  18.0   5.0  14.8  0.0  0     0
# 1        Brentford  ...  Match Report    NaN  19.0   8.0  13.6  1.0  0     0
# 2   Manchester Utd  ...  Match Report    NaN  11.0   3.0  13.4  0.0  0     0
# 3  Nott'ham Forest  ...  Match Report    NaN  14.0   5.0  14.9  0.0  0     0
# 5      Bournemouth  ...  Match Report    NaN  19.0  12.0  16.6  0.0  0     0
#
#   season       team
# ...

# %%
df.shape
# Out:
# (1020, 28)

# %%
df['team'].value_counts()
# Out:
# team
# Liverpool                 51
# Arsenal                   51
# Chelsea                   51
# BrightonandHoveAlbion     51
# ManchesterCity            51
# NottinghamForest          51
# TottenhamHotspur          51
# Brentford                 51
# ManchesterUnited          51
# Fulham                    51
# NewcastleUnited           51
# AstonVilla                51
# Bournemouth               51
# WestHamUnited             51
# Everton                   51
# CrystalPalace             51
# WolverhamptonWanderers    51
# Burnley                   38
# LutonTown                 38
# SheffieldUnited           38
# LeicesterCity             13
# IpswichTown               13
# Southampton               13
# Name: count, dtype: int64

# %%
df['round'].value_counts()
# Out:
# round
# Matchweek 1     40
# Matchweek 2     40
# Matchweek 3     40
# Matchweek 4     40
# Matchweek 5     40
# Matchweek 6     40
# Matchweek 7     40
# Matchweek 8     40
# Matchweek 9     40
# Matchweek 10    40
# Matchweek 11    40
# Matchweek 12    40
# Matchweek 13    40
# Matchweek 14    20
# Matchweek 15    20
# Matchweek 16    20
# Matchweek 17    20
# Matchweek 19    20
# Matchweek 20    20
# Matchweek 21    20
# Matchweek 22    20
# Matchweek 23    20
# Matchweek 24    20
# Matchweek 25    20
# Matchweek 18    20
# Matchweek 26    20
# Matchweek 27    20
# Matchweek 28    20
# Matchweek 30    20
# Matchweek 31    20
# Matchweek 32    20
# Matchweek 33    20
# Matchweek 29    20
# Matchweek 35    20
# Matchweek 36    20
# Matchweek 37    20
# Matchweek 34    20
# Matchweek 38    20
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# date              object
# time              object
# comp              object
# round             object
# day               object
# venue             object
# result            object
# gf               float64
# ga               float64
# opponent          object
# xg               float64
# xga              float64
# poss             float64
# attendance       float64
# captain           object
# formation         object
# opp formation     object
# referee           object
# match report      object
# notes            float64
# sh               float64
# sot              float64
# dist             float64
# fk               float64
# pk                 int64
# pkatt              int64
# season             int64
# team              object
# dtype: object

# %%
# ML work with numeric data only
# 1 convert date
df['date'] = pd.to_datetime(df['date'])
df.dtypes
# Out:
# date             datetime64[ns]
# time                     object
# comp                     object
# round                    object
# day                      object
# venue                    object
# result                   object
# gf                      float64
# ga                      float64
# opponent                 object
# xg                      float64
# xga                     float64
# poss                    float64
# attendance              float64
# captain                  object
# formation                object
# opp formation            object
# referee                  object
# match report             object
# notes                   float64
# sh                      float64
# sot                     float64
# dist                    float64
# fk                      float64
# pk                        int64
# pkatt                     int64
# season                    int64
# team                     object
# dtype: object

# %%
matches_df = pd.get_dummies(df, columns=['venue'], dtype=int, drop_first=True)
matches_df.head()
# Out:
#          date   time            comp        round  day result   gf   ga  \
# 0  2024-08-17  12:30  Premier League  Matchweek 1  Sat      W  2.0  0.0
# 1  2024-08-25  16:30  Premier League  Matchweek 2  Sun      W  2.0  0.0
# 2  2024-09-01  16:00  Premier League  Matchweek 3  Sun      W  3.0  0.0
# 3  2024-09-14  15:00  Premier League  Matchweek 4  Sat      L  0.0  1.0
# 5  2024-09-21  15:00  Premier League  Matchweek 5  Sat      W  3.0  0.0
#
#           opponent   xg  ...  notes    sh   sot  dist   fk pk pkatt season  \
# 0     Ipswich Town  2.6  ...    NaN  18.0   5.0  14.8  0.0  0     0   2024
# 1        Brentford  2.5  ...    NaN  19.0   8.0  13.6  1.0  0     0   2024
# 2   Manchester Utd  1.8  ...    NaN  11.0   3.0  13.4  0.0  0     0   2024
# 3  Nott'ham Forest  0.9  ...    NaN  14.0   5.0  14.9  0.0  0     0   2024
# 5      Bournemouth  2.0  ...    NaN  19.0  12.0  16.6  0.0  0     0   2024
#
#         team  venue_Home
# 0  Liverpool           0
# 1  Liverpool           1
# ...

# %% [markdown]
# We will use category codes like 0 1 2 3 4 and so on for opponent code

# %% [markdown]
# We will not use getdummies for sure because it so many team

# %%
matches_df['opp_code'] = matches_df['opponent'].astype('category').cat.codes
matches_df.head()
# Out:
#          date   time            comp        round  day result   gf   ga  \
# 0  2024-08-17  12:30  Premier League  Matchweek 1  Sat      W  2.0  0.0
# 1  2024-08-25  16:30  Premier League  Matchweek 2  Sun      W  2.0  0.0
# 2  2024-09-01  16:00  Premier League  Matchweek 3  Sun      W  3.0  0.0
# 3  2024-09-14  15:00  Premier League  Matchweek 4  Sat      L  0.0  1.0
# 5  2024-09-21  15:00  Premier League  Matchweek 5  Sat      W  3.0  0.0
#
#           opponent   xg  ...    sh   sot  dist   fk pk pkatt season  \
# 0     Ipswich Town  2.6  ...  18.0   5.0  14.8  0.0  0     0   2024
# 1        Brentford  2.5  ...  19.0   8.0  13.6  1.0  0     0   2024
# 2   Manchester Utd  1.8  ...  11.0   3.0  13.4  0.0  0     0   2024
# 3  Nott'ham Forest  0.9  ...  14.0   5.0  14.9  0.0  0     0   2024
# 5      Bournemouth  2.0  ...  19.0  12.0  16.6  0.0  0     0   2024
#
#         team  venue_Home  opp_code
# 0  Liverpool           0        10
# 1  Liverpool           1         3
# ...

# %%
matches_df['opp_code'].value_counts()
# Out:
# opp_code
# 16    165
# 26    165
# 7     165
# 4     165
# 1     165
# 0     165
# 6     165
# 13    165
# 17    165
# 22    165
# 15    165
# 25    165
# 8     165
# 12    127
# 3     127
# 9     127
# 21    127
# 11    114
# 5     114
# 19     89
# 2      89
# 20     76
# 14     38
# 23     38
# 18     38
# 24     38
# 10     13
# Name: count, dtype: int64

# %%
team_code = matches_df[['opponent', 'opp_code']].drop_duplicates()
team_code.to_csv('team_code.csv')

# %%
matches_df['hour'] = matches_df['time'].str.replace(':.+', '', regex=True).astype('int')

# %%
matches_df.head()
# Out:
#         date   time            comp        round  day result   gf   ga  \
# 0 2024-08-17  12:30  Premier League  Matchweek 1  Sat      W  2.0  0.0
# 1 2024-08-25  16:30  Premier League  Matchweek 2  Sun      W  2.0  0.0
# 2 2024-09-01  16:00  Premier League  Matchweek 3  Sun      W  3.0  0.0
# 3 2024-09-14  15:00  Premier League  Matchweek 4  Sat      L  0.0  1.0
# 5 2024-09-21  15:00  Premier League  Matchweek 5  Sat      W  3.0  0.0
#
#           opponent   xg  ...   sot  dist   fk pk pkatt season       team  \
# 0     Ipswich Town  2.6  ...   5.0  14.8  0.0  0     0   2024  Liverpool
# 1        Brentford  2.5  ...   8.0  13.6  1.0  0     0   2024  Liverpool
# 2   Manchester Utd  1.8  ...   3.0  13.4  0.0  0     0   2024  Liverpool
# 3  Nott'ham Forest  0.9  ...   5.0  14.9  0.0  0     0   2024  Liverpool
# 5      Bournemouth  2.0  ...  12.0  16.6  0.0  0     0   2024  Liverpool
#
#   venue_Home  opp_code  hour
# 0          0        10    12
# 1          1         3    16
# ...

# %%
matches_df['day_code'] = matches_df['date'].dt.day_of_week
matches_df.head(5)
# Out:
#         date   time            comp        round  day result   gf   ga  \
# 0 2024-08-17  12:30  Premier League  Matchweek 1  Sat      W  2.0  0.0
# 1 2024-08-25  16:30  Premier League  Matchweek 2  Sun      W  2.0  0.0
# 2 2024-09-01  16:00  Premier League  Matchweek 3  Sun      W  3.0  0.0
# 3 2024-09-14  15:00  Premier League  Matchweek 4  Sat      L  0.0  1.0
# 5 2024-09-21  15:00  Premier League  Matchweek 5  Sat      W  3.0  0.0
#
#           opponent   xg  ...  dist   fk  pk pkatt season       team  \
# 0     Ipswich Town  2.6  ...  14.8  0.0   0     0   2024  Liverpool
# 1        Brentford  2.5  ...  13.6  1.0   0     0   2024  Liverpool
# 2   Manchester Utd  1.8  ...  13.4  0.0   0     0   2024  Liverpool
# 3  Nott'ham Forest  0.9  ...  14.9  0.0   0     0   2024  Liverpool
# 5      Bournemouth  2.0  ...  16.6  0.0   0     0   2024  Liverpool
#
#   venue_Home opp_code  hour  day_code
# 0          0       10    12         5
# 1          1        3    16         6
# ...

# %%
matches_df['target'] = matches_df['result']
mapping_result = {
    'W' : 1,
    'D' : 0,
    'L' : 0,
}
matches_df['target'] = matches_df['target'].map(mapping_result)
matches_df.head()
# Out:
#         date   time            comp        round  day result   gf   ga  \
# 0 2024-08-17  12:30  Premier League  Matchweek 1  Sat      W  2.0  0.0
# 1 2024-08-25  16:30  Premier League  Matchweek 2  Sun      W  2.0  0.0
# 2 2024-09-01  16:00  Premier League  Matchweek 3  Sun      W  3.0  0.0
# 3 2024-09-14  15:00  Premier League  Matchweek 4  Sat      L  0.0  1.0
# 5 2024-09-21  15:00  Premier League  Matchweek 5  Sat      W  3.0  0.0
#
#           opponent   xg  ...   fk  pk  pkatt season       team venue_Home  \
# 0     Ipswich Town  2.6  ...  0.0   0      0   2024  Liverpool          0
# 1        Brentford  2.5  ...  1.0   0      0   2024  Liverpool          1
# 2   Manchester Utd  1.8  ...  0.0   0      0   2024  Liverpool          0
# 3  Nott'ham Forest  0.9  ...  0.0   0      0   2024  Liverpool          1
# 5      Bournemouth  2.0  ...  0.0   0      0   2024  Liverpool          1
#
#   opp_code hour  day_code  target
# 0       10   12         5       1
# ...

# %%
matches_df.dtypes
# Out:
# date             datetime64[ns]
# time                     object
# comp                     object
# round                    object
# day                      object
# result                   object
# gf                      float64
# ga                      float64
# opponent                 object
# xg                      float64
# xga                     float64
# poss                    float64
# attendance              float64
# captain                  object
# formation                object
# opp formation            object
# referee                  object
# match report             object
# notes                   float64
# sh                      float64
# sot                     float64
# dist                    float64
# fk                      float64
# pk                        int64
# pkatt                     int64
# season                    int64
# team                     object
# venue_Home                int64
# opp_code                   int8
# ...

# %%
matches_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3300 entries, 0 to 42
# Data columns (total 32 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           3300 non-null   datetime64[ns]
#  1   time           3300 non-null   object
#  2   comp           3300 non-null   object
#  3   round          3300 non-null   object
#  4   day            3300 non-null   object
#  5   result         3300 non-null   object
#  6   gf             3300 non-null   float64
#  7   ga             3300 non-null   float64
#  8   opponent       3300 non-null   object
#  9   xg             3300 non-null   float64
#  10  xga            3300 non-null   float64
#  11  poss           3300 non-null   float64
#  12  attendance     2592 non-null   float64
#  13  captain        3300 non-null   object
#  14  formation      3300 non-null   object
#  15  opp formation  3300 non-null   object
#  16  referee        3300 non-null   object
# ...

# %%
matches_df.head()
# Out:
#         date   time            comp        round  day result   gf   ga  \
# 0 2024-08-17  12:30  Premier League  Matchweek 1  Sat      W  2.0  0.0
# 1 2024-08-25  16:30  Premier League  Matchweek 2  Sun      W  2.0  0.0
# 2 2024-09-01  16:00  Premier League  Matchweek 3  Sun      W  3.0  0.0
# 3 2024-09-14  15:00  Premier League  Matchweek 4  Sat      L  0.0  1.0
# 5 2024-09-21  15:00  Premier League  Matchweek 5  Sat      W  3.0  0.0
#
#           opponent   xg  ...   fk  pk  pkatt season       team venue_Home  \
# 0     Ipswich Town  2.6  ...  0.0   0      0   2024  Liverpool          0
# 1        Brentford  2.5  ...  1.0   0      0   2024  Liverpool          1
# 2   Manchester Utd  1.8  ...  0.0   0      0   2024  Liverpool          0
# 3  Nott'ham Forest  0.9  ...  0.0   0      0   2024  Liverpool          1
# 5      Bournemouth  2.0  ...  0.0   0      0   2024  Liverpool          1
#
#   opp_code hour  day_code  target
# 0       10   12         5       2
# ...

# %%
matches_df.columns
# Out:
# Index(['date', 'time', 'comp', 'round', 'day', 'result', 'gf', 'ga',
#        'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain', 'formation',
#        'opp formation', 'referee', 'match report', 'notes', 'sh', 'sot',
#        'dist', 'fk', 'pk', 'pkatt', 'season', 'team', 'venue_Home', 'opp_code',
#        'hour', 'day_code', 'target'],
#       dtype='object')

# %%
matches_df[matches_df['date'] < '2024-05-20'].shape[0]
# Out:
# 3040

# %%
matches_df[matches_df['date'] > '2024-05-20'].shape[0]
# Out:
# 260

# %%
# we use classifier model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

predictors = ['venue_Home', 'opp_code', 'hour', 'day_code']
target = ['target']
X = matches_df[predictors]
y = matches_df[target]

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.3, random_state=141)

grid_search = GridSearchCV(
    estimator=RandomForestClassifier(),
    param_grid=dict(
        n_estimators=[50, 100, 200, 300, 400, 500], 
        min_samples_split=[2, 5, 10, 15, 20, 25, 30, 40],  
        min_samples_leaf=[1,10,20,30],      
        random_state=[1],
    ),                                      
        scoring='f1_weighted',             
        cv=5,                                
        n_jobs=-1                            
)
grid_search.fit(X_train, y_train)

model = grid_search.best_estimator_
# Out:
# c:\Users\phumi\anaconda3\envs\predict-football\Lib\site-packages\numpy\ma\core.py:2881: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# c:\Users\phumi\anaconda3\envs\predict-football\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
grid_search.best_params_
# Out:
# {'min_samples_leaf': 10,
#  'min_samples_split': 25,
#  'n_estimators': 400,
#  'random_state': 1}

# %%
predictions = model.predict(X_test)
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test,predictions,digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.4586    0.5169    0.4861       118
#            1     0.2353    0.0563    0.0909        71
#            2     0.4808    0.6410    0.5495       117
#
#     accuracy                         0.4575       306
#    macro avg     0.3916    0.4048    0.3755       306
# weighted avg     0.4153    0.4575    0.4186       306

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[61 15 42]
#  [32  4 35]
#  [44  1 72]]

# %% [markdown]
# Improve precision with rolling averages

# %%
grouped_matches = matches_df.groupby('team')
group = grouped_matches.get_group('Liverpool')
group.head()
# Out:
#         date   time            comp        round  day result   gf   ga  \
# 0 2024-08-17  12:30  Premier League  Matchweek 1  Sat      W  2.0  0.0
# 1 2024-08-25  16:30  Premier League  Matchweek 2  Sun      W  2.0  0.0
# 2 2024-09-01  16:00  Premier League  Matchweek 3  Sun      W  3.0  0.0
# 3 2024-09-14  15:00  Premier League  Matchweek 4  Sat      L  0.0  1.0
# 5 2024-09-21  15:00  Premier League  Matchweek 5  Sat      W  3.0  0.0
#
#           opponent   xg  ...   fk  pk  pkatt season       team venue_Home  \
# 0     Ipswich Town  2.6  ...  0.0   0      0   2024  Liverpool          0
# 1        Brentford  2.5  ...  1.0   0      0   2024  Liverpool          1
# 2   Manchester Utd  1.8  ...  0.0   0      0   2024  Liverpool          0
# 3  Nott'ham Forest  0.9  ...  0.0   0      0   2024  Liverpool          1
# 5      Bournemouth  2.0  ...  0.0   0      0   2024  Liverpool          1
#
#   opp_code hour  day_code  target
# 0       10   12         5       1
# ...

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values('date')
    # closed = 'left' is take the current week out
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ['gf', 'ga', 'sh', 'sot', 'dist', 'fk', 'pk', 'pkatt', 'xg', 'xga']
new_cols = [f'{c}_rollinig' for c in cols]
new_cols
# Out:
# ['gf_rollinig',
#  'ga_rollinig',
#  'sh_rollinig',
#  'sot_rollinig',
#  'dist_rollinig',
#  'fk_rollinig',
#  'pk_rollinig',
#  'pkatt_rollinig',
#  'xg_rollinig',
#  'xga_rollinig']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day result   gf   ga  \
# 3  2023-09-03  14:00  Premier League   Matchweek 4  Sun      W  3.0  0.0
# 4  2023-09-16  12:30  Premier League   Matchweek 5  Sat      W  3.0  1.0
# 6  2023-09-24  14:00  Premier League   Matchweek 6  Sun      W  3.0  1.0
# 8  2023-09-30  17:30  Premier League   Matchweek 7  Sat      L  1.0  2.0
# 10 2023-10-08  14:00  Premier League   Matchweek 8  Sun      D  2.0  2.0
# 11 2023-10-21  12:30  Premier League   Matchweek 9  Sat      W  2.0  0.0
# 13 2023-10-29  14:00  Premier League  Matchweek 10  Sun      W  3.0  0.0
# 15 2023-11-05  16:30  Premier League  Matchweek 11  Sun      D  1.0  1.0
# 17 2023-11-12  14:00  Premier League  Matchweek 12  Sun      W  3.0  0.0
# 18 2023-11-25  12:30  Premier League  Matchweek 13  Sat      D  1.0  1.0
# 20 2023-12-03  14:00  Premier League  Matchweek 14  Sun      W  4.0  3.0
# 21 2023-12-06  19:30  Premier League  Matchweek 15  Wed      W  2.0  0.0
# ...

# %%
matches_rolling = matches_df.groupby('team').apply(lambda x : rolling_averages(x,cols, new_cols))
# Out:
# C:\Users\phumi\AppData\Local\Temp\ipykernel_6652\4214989607.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches_df.groupby('team').apply(lambda x : rolling_averages(x,cols, new_cols))

# %%
matches_rolling
# Out:
#                                 date   time            comp         round  \
# team
# Arsenal                6  2020-10-04  14:00  Premier League   Matchweek 4
#                        7  2020-10-17  17:30  Premier League   Matchweek 5
#                        9  2020-10-25  19:15  Premier League   Matchweek 6
#                        11 2020-11-01  16:30  Premier League   Matchweek 7
#                        13 2020-11-08  19:15  Premier League   Matchweek 8
# ...                              ...    ...             ...           ...
# WolverhamptonWanderers 10 2024-10-26  15:00  Premier League   Matchweek 9
#                        11 2024-11-02  17:30  Premier League  Matchweek 10
#                        12 2024-11-09  15:00  Premier League  Matchweek 11
#                        13 2024-11-23  15:00  Premier League  Matchweek 12
#                        14 2024-11-30  15:00  Premier League  Matchweek 13
#
# ...

# %%
matches_rolling = matches_rolling.droplevel('team')
matches_rolling
# Out:
#          date   time            comp         round  day result   gf   ga  \
# 6  2020-10-04  14:00  Premier League   Matchweek 4  Sun      W  2.0  1.0
# 7  2020-10-17  17:30  Premier League   Matchweek 5  Sat      L  0.0  1.0
# 9  2020-10-25  19:15  Premier League   Matchweek 6  Sun      L  0.0  1.0
# 11 2020-11-01  16:30  Premier League   Matchweek 7  Sun      W  1.0  0.0
# 13 2020-11-08  19:15  Premier League   Matchweek 8  Sun      L  0.0  3.0
# ..        ...    ...             ...           ...  ...    ...  ...  ...
# 10 2024-10-26  15:00  Premier League   Matchweek 9  Sat      D  2.0  2.0
# 11 2024-11-02  17:30  Premier League  Matchweek 10  Sat      D  2.0  2.0
# 12 2024-11-09  15:00  Premier League  Matchweek 11  Sat      W  2.0  0.0
# 13 2024-11-23  15:00  Premier League  Matchweek 12  Sat      W  4.0  1.0
# 14 2024-11-30  15:00  Premier League  Matchweek 13  Sat      L  2.0  4.0
#
#            opponent   xg  ...  gf_rollinig  ga_rollinig  sh_rollinig  \
# ...

# %%
matches_rolling.index = range(matches_rolling.shape[0])
matches_rolling
# Out:
#            date   time            comp         round  day result   gf   ga  \
# 0    2020-10-04  14:00  Premier League   Matchweek 4  Sun      W  2.0  1.0
# 1    2020-10-17  17:30  Premier League   Matchweek 5  Sat      L  0.0  1.0
# 2    2020-10-25  19:15  Premier League   Matchweek 6  Sun      L  0.0  1.0
# 3    2020-11-01  16:30  Premier League   Matchweek 7  Sun      W  1.0  0.0
# 4    2020-11-08  19:15  Premier League   Matchweek 8  Sun      L  0.0  3.0
# ...         ...    ...             ...           ...  ...    ...  ...  ...
# 3211 2024-10-26  15:00  Premier League   Matchweek 9  Sat      D  2.0  2.0
# 3212 2024-11-02  17:30  Premier League  Matchweek 10  Sat      D  2.0  2.0
# 3213 2024-11-09  15:00  Premier League  Matchweek 11  Sat      W  2.0  0.0
# 3214 2024-11-23  15:00  Premier League  Matchweek 12  Sat      W  4.0  1.0
# 3215 2024-11-30  15:00  Premier League  Matchweek 13  Sat      L  2.0  4.0
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

predictors = ['venue_Home', 'opp_code', 'hour', 'day_code']
new_predtictors = predictors + new_cols
target = ['target']
X = matches_rolling[new_predtictors]
y = matches_rolling[target]

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=1)

grid_search = GridSearchCV(
    estimator=RandomForestClassifier(),
    param_grid=dict(
        n_estimators=[50, 100, 200], 
        min_samples_split=[2, 5],  
        min_samples_leaf=[1, 10],      
        random_state=[1],
    ),                                      
        scoring='f1_weighted',             
        cv=5,                                
        n_jobs=-1                            
)
grid_search.fit(X_train, y_train)

RFmodel = grid_search.best_estimator_
# Out:
# c:\Users\phumi\anaconda3\envs\predict-football\Lib\site-packages\numpy\ma\core.py:2881: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# c:\Users\phumi\anaconda3\envs\predict-football\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
grid_search.best_params_
# Out:
# {'min_samples_leaf': 1,
#  'min_samples_split': 5,
#  'n_estimators': 200,
#  'random_state': 141}

# %%
predictions = RFmodel.predict(X_test)
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test,predictions,digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.6586    0.8304    0.7346       395
#            1     0.5411    0.3173    0.4000       249
#
#     accuracy                         0.6320       644
#    macro avg     0.5999    0.5738    0.5673       644
# weighted avg     0.6132    0.6320    0.6052       644

# %%
predictors = ['venue_Home', 'opp_code', 'hour', 'day_code']
cols = ['gf', 'ga', 'sh', 'sot', 'dist', 'fk', 'pk', 'pkatt', 'xg', 'xga']
new_cols = [f'{c}_rollinig' for c in cols]
input = predictors + new_cols
input
# Out:
# ['venue_Home',
#  'opp_code',
#  'hour',
#  'day_code',
#  'gf_rollinig',
#  'ga_rollinig',
#  'sh_rollinig',
#  'sot_rollinig',
#  'dist_rollinig',
#  'fk_rollinig',
#  'pk_rollinig',
#  'pkatt_rollinig',
#  'xg_rollinig',
#  'xga_rollinig']

# %% [markdown]
# XGBoost

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

predictors = ['venue_Home', 'opp_code', 'hour', 'day_code']
new_predtictors = predictors + new_cols
target = ['target']
X = matches_rolling[new_predtictors]
y = matches_rolling[target]

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=1)

param_grid = {
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7],
    'n_estimators': [50, 100, 200],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.8, 1.0],
    'scale_pos_weight': [1, 2]
}
grid_search = GridSearchCV(
    estimator=XGBClassifier(random_state=1),
    param_grid=param_grid,                                      
    scoring='f1_weighted',             
    cv=5,                                
    n_jobs=-1                            
)
grid_search.fit(X_train, y_train)

XGBoostmodel = grid_search.best_estimator_

# %%
grid_search.best_params_
# Out:
# {'colsample_bytree': 0.8,
#  'learning_rate': 0.2,
#  'max_depth': 3,
#  'n_estimators': 100,
#  'scale_pos_weight': 1,
#  'subsample': 0.6}

# %%
predictions = XGBoostmodel.predict(X_test)
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test,predictions,digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.6992    0.8354    0.7612       395
#            1     0.6221    0.4297    0.5083       249
#
#     accuracy                         0.6786       644
#    macro avg     0.6606    0.6326    0.6348       644
# weighted avg     0.6694    0.6786    0.6635       644

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[317  78]
#  [147 102]]

# %% [markdown]
# Save Model (XGBoost)

# %%
import pickle
filename = 'XGBoostmodel.pkl'
pickle.dump(XGBoostmodel, open(filename, 'wb'))

# %%
X_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 X_test
#
# NameError: name 'X_test' is not defined
